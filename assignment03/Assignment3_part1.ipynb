# %% [markdown]
# # Assignment 3 - Epipolar Geometry and 3D Reconstruction
#
# First name: Ramon
# <br>
# Last name: Näf
# <br>
# Matriculation number: 20-116-950

# %%
# !pip install ipyvolume
# Out:
# Requirement already satisfied: ipyvolume in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (0.6.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (8.1.7)
# Requirement already satisfied: bqplot in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (0.12.45)
# Requirement already satisfied: numpy in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (2.2.6)
# Requirement already satisfied: traittypes in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (0.2.3)
# Requirement already satisfied: traitlets in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (5.14.3)
# Requirement already satisfied: Pillow in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (11.3.0)
# Requirement already satisfied: ipywebrtc in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (0.6.0)
# Requirement already satisfied: requests in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (2.32.5)
# Requirement already satisfied: ipyvuetify in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (1.11.3)
# Requirement already satisfied: ipyvue>=1.7.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (1.11.3)
# Requirement already satisfied: pythreejs>=2.4.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (2.4.2)
# Requirement already satisfied: matplotlib in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipyvolume) (3.10.7)
# Requirement already satisfied: comm>=0.1.3 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipywidgets>=7.0.0->ipyvolume) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipywidgets>=7.0.0->ipyvolume) (9.6.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipywidgets>=7.0.0->ipyvolume) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipywidgets>=7.0.0->ipyvolume) (3.0.15)
# Requirement already satisfied: colorama in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.4.6)
# Requirement already satisfied: decorator in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.8.5)
# Requirement already satisfied: ipydatawidgets>=1.1.1 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from pythreejs>=2.4.0->ipyvolume) (4.3.5)
# Requirement already satisfied: pandas<3.0.0,>=1.0.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from bqplot->ipyvolume) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from pandas<3.0.0,>=1.0.0->bqplot->ipyvolume) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from pandas<3.0.0,>=1.0.0->bqplot->ipyvolume) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from pandas<3.0.0,>=1.0.0->bqplot->ipyvolume) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=1.0.0->bqplot->ipyvolume) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from matplotlib->ipyvolume) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from matplotlib->ipyvolume) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from matplotlib->ipyvolume) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from matplotlib->ipyvolume) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from matplotlib->ipyvolume) (25.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from matplotlib->ipyvolume) (3.2.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from requests->ipyvolume) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from requests->ipyvolume) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from requests->ipyvolume) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from requests->ipyvolume) (2025.10.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\cptmeh\documents\uni\info\semester_11\cv\cv_hs25\.venv\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets>=7.0.0->ipyvolume) (0.2.3)

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import os

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import ipyvolume as ipv

from data import load_homogeneous_coordinates
from utils import eight_points_algorithm, right_epipole, plot_epipolar_line
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 7
#       5 import matplotlib.pyplot as plt
#       6 from PIL import Image
# ----> 7 import ipyvolume as ipv
#       9 from data import load_homogeneous_coordinates
#      10 from utils import eight_points_algorithm, right_epipole, plot_epipolar_line
#
# File c:\Users\CptMeh\Documents\Uni\INFO\semester_11\CV\CV_HS25\.venv\Lib\site-packages\ipyvolume\__init__.py:8
#       6 from ipyvolume import datasets  # noqa: F401
#       7 from ipyvolume import embed  # noqa: F401
# ----> 8 from ipyvolume.widgets import *  # noqa: F401, F403
#       9 from ipyvolume.transferfunction import *  # noqa: F401, F403
#      10 from ipyvolume.pylab import *  # noqa: F401, F403
#
# File c:\Users\CptMeh\Documents\Uni\INFO\semester_11\CV\CV_HS25\.venv\Lib\site-packages\ipyvolume\widgets.py:30
#      22 from ipyvolume.traittypes import Image
#      23 from ipyvolume.serialize import (
#      24     array_cube_tile_serialization,
#      25     array_serialization,
#    (...)     28     texture_serialization,
#      29 )
# ---> 30 from ipyvolume.transferfunction import TransferFunction
#      31 from ipyvolume.utils import debounced, grid_slice, reduce_size
#      34 _last_figure = None
#
# File c:\Users\CptMeh\Documents\Uni\INFO\semester_11\CV\CV_HS25\.venv\Lib\site-packages\ipyvolume\transferfunction.py:19
#      17 N = 1024
#      18 x = np.linspace(0, 1, N, endpoint=True)
# ---> 19 semver_range_frontend = "~" + ipyvolume._version.__version_js__
#      22 @widgets.register
#      23 class TransferFunction(widgets.DOMWidget):
#      24     _model_name = Unicode('TransferFunctionModel').tag(sync=True)
#
# AttributeError: partially initialized module 'ipyvolume' has no attribute '_version' (most likely due to a circular import)

# %% [markdown]
# ## Part I: The Eight Point Algorithm

# %% [markdown]
# ### Load Data

# %%
data_dir = './merton_college/'
img1, img2, x1, x2 = load_homogeneous_coordinates(data_dir)

# %% [markdown]
# ### Estimate the fundamental matrix F

# %%
# TODO: implement this function
F = eight_points_algorithm(x1, x2) 
assert np.linalg.matrix_rank(F) == 2
print('Estimated fundamental matrix: ')
print(F)

# %% [markdown]
# ### Plot epipoles and epipolar lines

# %%
# compute the epipole
# TODO: implement this function
e = right_epipole(F)

# %%
plt.figure()
plt.imshow(img1)
plt.title('Image 1')

# plot each line individually, this gives nice colors
for i in range(100, 105): 
    # TODO: implement this function 
    plot_epipolar_line(img1, F.T, x2[:, i], e)

plt.axis('off')
plt.figure()
plt.imshow(img2)
plt.title('Image 2')

# plot each point individually, this gives same colors as the lines 
for i in range(100, 105):
    plt.plot(x2[0, i], x2[1, i], 'o')
    plt.axis('off')

# %%
# %matplotlib notebook
#if it dosn't work for you, switch to `matplotlib widget`, but make sure you have ipympl installed.

# %matplotlib widget

from ipywidgets import *

fig, ax = plt.subplots()
ax.imshow(img1)

fig2, ax2 = plt.subplots()
ax2.imshow(img2)

def onclick(event):
    ax.plot(event.xdata, event.ydata, 'o')
    plot_epipolar_line(img2, F, np.array([event.xdata, event.ydata, 1]), e, ax2)
    ax2.imshow(img2)

cid = fig.canvas.mpl_connect('button_press_event', onclick)
